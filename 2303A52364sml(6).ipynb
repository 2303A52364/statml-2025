# %% [markdown]
# Question 1:

# %% [markdown]
# Imagine you are developing a simple machine learning model to predict whether a student will pass a course based on the following five features:
#
# 1.Study Hours per Week: Number of hours the student studies per week.
#
# 2.Class Attendance (%): Percentage of classes attended by the student.
#
# 3.Previous Exam Score (%): Score in the previous exam.
#
# 4.Participation in Group Study: Whether the student participates in group study sessions (1 for Yes, 0 for No).
#
# 5.Submission of Assignments (%): Percentage of assignments submitted by the student.

# %%
import pandas as pd
data = [[10, 90, 85, 1, 100, 1],
        [5, 60, 70, 0, 80, 0],
        [15, 95, 90, 1, 100, 1],
        [2, 30, 50, 0, 40, 0],
        [12, 85, 88, 1, 90, 1],
        [8, 75, 65, 0, 70, 0],
        [14, 92, 93, 1, 95, 1],
        [3, 50, 55, 0, 60, 0],
        [11, 88, 80, 1, 85, 1],
        [6, 65, 60, 0, 75, 0]]
df = pd.DataFrame(data, columns=['Study Hours per Week', 'Class Attendance (%)', 'Previous Exam Score (%)', 'Participation in Group Study', 'Submission of Assignments (%)', 'Pass/Fail'])
df
# Out:
#    Study Hours per Week  Class Attendance (%)  Previous Exam Score (%)  \
# 0                    10                    90                       85
# 1                     5                    60                       70
# 2                    15                    95                       90
# 3                     2                    30                       50
# 4                    12                    85                       88
# 5                     8                    75                       65
# 6                    14                    92                       93
# 7                     3                    50                       55
# 8                    11                    88                       80
# 9                     6                    65                       60
#
#    Participation in Group Study  Submission of Assignments (%)  Pass/Fail
# 0                             1                            100          1
# 1                             0                             80          0
# 2                             1                            100          1
# 3                             0                             40          0
# 4                             1                             90          1
# 5                             0                             70          0
# 6                             1                             95          1
# 7                             0                             60          0
# 8                             1                             85          1
# 9                             0                             75          0

# %%
df.to_csv('student_data.csv', index=False)
df
# Out:
#    Study Hours per Week  Class Attendance (%)  Previous Exam Score (%)  \
# 0                    10                    90                       85
# 1                     5                    60                       70
# 2                    15                    95                       90
# 3                     2                    30                       50
# 4                    12                    85                       88
# 5                     8                    75                       65
# 6                    14                    92                       93
# 7                     3                    50                       55
# 8                    11                    88                       80
# 9                     6                    65                       60
#
#    Participation in Group Study  Submission of Assignments (%)  Pass/Fail
# 0                             1                            100          1
# 1                             0                             80          0
# 2                             1                            100          1
# 3                             0                             40          0
# 4                             1                             90          1
# 5                             0                             70          0
# 6                             1                             95          1
# 7                             0                             60          0
# 8                             1                             85          1
# 9                             0                             75          0

# %%
x = df.drop('Pass/Fail', axis=1)
y = df['Pass/Fail']

# %%
import numpy as np
list=[2.0,3.0,7.0,1.0,5.0]
weight = np.array(list)
weight
# Out:
# array([2., 3., 7., 1., 5.])

# %%
def update(p,e,i):
    for j in range(len(weight)):
        weight[j]=weight[j]+p*e*float(x.iloc[i:i+1,j:j+1].values)

# %%
print(x.iloc[0:1,1:2])
# Out:
#    Class Attendance (%)
# 0                    90

# %%
learning_rate = 0.001
def error(yp,i):
  e=y[i]-yp
  if(e!=0): # removed extra indent
    update(learning_rate,e,i)

# %%
print("Trained Weights:", weight)

# Prediction Function
def perceptron_predict(x, weights):
    z = np.dot(x, weights)
    return 1 if z >= 0 else 0 # removed extra indent

        # Test the model
correct_predictions = 0
for i in range(len(x)):
  prediction = perceptron_predict(x[i:i+1], weight)
  if prediction == y[i]:
    correct_predictions += 1

                        # Accuracy calculation
accuracy = correct_predictions / len(x)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Trained Weights: [2. 3. 7. 1. 5.]
# Accuracy: 50.00%

# %% [markdown]
# questin 2

# %% [markdown]
# Implement a perceptron learning model to train above data, and find the accuracy.

# %%
import pandas as pd
diabetes=pd.read_csv('/content/diabetes_data_upload.csv')
diabetes.head()
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
# 4             No             Yes     Yes          Yes             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity     class
# 0              No              Yes      Yes     Yes  Positive
# 1             Yes               No      Yes      No  Positive
# 2              No              Yes      Yes      No  Positive
# 3              No               No       No      No  Positive
# 4             Yes              Yes      Yes     Yes  Positive

# %%
target_var=diabetes['class']
target_var.head()
# Out:
# 0    Positive
# 1    Positive
# 2    Positive
# 3    Positive
# 4    Positive
# Name: class, dtype: object

# %%
one_values = ["Male", "Yes"]
zero_values = ["Female","No"]

# %%
# Define the features variable. Assumed to be all columns of the diabetes dataframe except the 'class' column.
features = diabetes.drop('class', axis=1)

for column in features.columns:
    features[column] = features[column].replace(to_replace=one_values, value=1)
    features[column] = features[column].replace(to_replace=zero_values, value=0) # This line was incorrectly indented. It is now aligned with line 5
    features

# %%
one_values = ["Positive"]
zero_values = ["Negative"]

target_var = target_var.replace(to_replace=one_values, value=1)
target_var= target_var.replace(to_replace=zero_values, value=0)
target_var.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: class, dtype: int64

# %%
import numpy as np

# %%
list1 = [0.21, 0.60, 0.78, 0.22, 0.62 ,
         0.53, 0.39, 0.036, 0.04 , 0.87,
         0.89, 0.13, 0.79, 0.13, 0.50,
         0.80]
weights=np.array(list1)
weights
# Out:
# array([0.21 , 0.6  , 0.78 , 0.22 , 0.62 , 0.53 , 0.39 , 0.036, 0.04 ,
#        0.87 , 0.89 , 0.13 , 0.79 , 0.13 , 0.5  , 0.8  ])

# %%
features.iloc[0:1].values
# Out:
# array([[40,  1,  0,  1,  0,  1,  0,  0,  0,  1,  0,  1,  0,  1,  1,  1]])

# %%
def update(p,e,i):
    for j in range(len(weights)):
        weights[j]=weights[j]+p*e*float(features.iloc[i:i+1,j:j+1].values)

# %%
cp=0
learning_rate = 0.001
def error(yp,i):
  e=target_var[i]-yp # Define e in the function's scope
  if(e!=0):
        update(learning_rate,e,i)
  return cp

# %%
yp=-1
import numpy as np
for k in range(6):
  for i in range (len(features)):
    z=np.dot(features[i:i+1],weights) #This line was incorrectly indented
    if z>0: #This line was incorrectly indented
      yp=1
    else: #This line was incorrectly indented
      yp=0
    error(yp,i) #This line was incorrectly indented
# Out:
# <ipython-input-59-6f8be6b0eac9>:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   weights[j]=weights[j]+p*e*float(features.iloc[i:i+1,j:j+1].values)

# %%
print("Trained Weights:", weights)

# Prediction Function
def perceptron_predict(x, weights):
    z = np.dot(x, weights)
    return 1 if z >= 0 else 0 # Remove the unexpected indentation

    # Test the model
correct_predictions = 0
for i in range(len(features)):
  prediction = perceptron_predict(features[i:i+1], weights)
  if prediction == target_var[i]:
    correct_predictions += 1

    # Accuracy calculation
accuracy = correct_predictions / len(features)
print(f"Accuracy: {accuracy * 100:.2f}%") # Remove the unexpected indentations
# Out:
# Trained Weights: [-0.039  0.517  0.823  0.298  0.649  0.54   0.379  0.03   0.041  0.781
#   0.881  0.083  0.822  0.087  0.429  0.797]
# Accuracy: 74.04%
