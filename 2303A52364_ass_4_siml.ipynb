# %% [markdown]
# From the above data:
#
# Read the data with pandas and find features and target variables
# Normalize the data with min-max scaling
# Split the data into train and test.

# %%
import pandas as pd
df = pd.read_csv("/content/train.csv")
#print(df)
#1
target = df.columns[-1]
y=df[target]
print(y)
cf =df.drop('price_range',axis=1) # Use 'df' instead of 'data'
print(cf)

#2
bf = cf-cf.min()/(cf.max()-cf.min())
print(bf)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(bf,y,test_size=0.2) # Use column names 'cf' to select features
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# ...

# %% [markdown]
# Download the dataset from the above link.
#
# Read the data with pandas and describe the data
# Find data type and shape of each column
# Find the target and features
# Find the null values (if yes fill the null values with ‘0’ or mean of that column)
# Normalize all the features
# Split the data into train and test.

# %%
import pandas as pd
data=pd.read_csv("/content/train.csv")
print(data)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
#question2
import pandas as pd
df = pd.read_csv("/content/sample_data/california_housing_train.csv")
print(df)
#1
print(df.describe())
#2
print(df.dtypes)
print(df.shape)

#3
#TARGET
y = df['median_house_value']
print(y)
#FEATURES
x=df.drop('median_house_value',axis=1)
print(x)
#4
null=df.isnull()
null
#5
normalised=df-x.min()/x.max()-x.min()
normalised
#6
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(normalised,y,test_size=0.2,random_state=30)
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...
